# %% [markdown]
# # Diabetes Prediction using Machine Learning
#
# ## Pima Indians Diabetes Dataset Analysis
#
# **Author:** Mohammad Nakibul Ezaz
#
# **Objective:** Binary classification to predict diabetes presence.

# %%
# %matplotlib inline

import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path

# Adds the parent directory to the search path
sys.path.append(os.path.abspath(".."))

from src.config import RAW_DATA_PATH, FIGURES_DIR
from src.data_loader import load_raw_data
from src.visualization import (
    plot_class_distribution,
    plot_feature_distributions,
    plot_correlation_matrix,
)

df = load_raw_data(RAW_DATA_PATH)
df.head()
# Out:
# [2026-03-25 10:01:42] [src.data_loader] [INFO] Loading raw data from D:\Portfolio Projects\diabetes-ml-prediction\data\raw\diabetes.csv
# [2026-03-25 10:01:42] [src.data_loader] [INFO] Loaded dataset with shape (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## Dataset Overview

# %%
print("Dataset Shape:", df.shape)
print("\nData Types:\n", df.dtypes)
print("\nMissing Values:\n", df.isnull().sum())
print("\nDuplicate Rows:", df.duplicated().sum())
df.describe()
# Out:
# Dataset Shape: (768, 9)
#
# Data Types:
#  Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object
#
# Missing Values:
#  Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
#
# Duplicate Rows: 0
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# ...

# %% [markdown]
# ## Class Distribution Analysis

# %%
y = df["Outcome"]
plot_class_distribution(y, FIGURES_DIR / "class_distribution.png")
# Out:
# [2026-03-25 10:02:41] [src.visualization] [INFO] Plotting class distribution
# [2026-03-25 10:02:42] [src.visualization] [INFO] Saved class distribution figure to D:\Portfolio Projects\diabetes-ml-prediction\reports\figures\class_distribution.png

# %% [markdown]
# ## Feature Engineering – Univariate & Bivariate Analysis

# %%
X = df.drop(columns=["Outcome"])
plot_feature_distributions(X, FIGURES_DIR / "feature_distributions.png")
# Out:
# [2026-03-25 10:03:02] [src.visualization] [INFO] Plotting feature distributions
# [2026-03-25 10:03:05] [src.visualization] [INFO] Saved feature distributions figure to D:\Portfolio Projects\diabetes-ml-prediction\reports\figures\feature_distributions.png

# %% [markdown]
# ### Feature Correlation Analysis

# %%
plot_correlation_matrix(df, FIGURES_DIR / "correlation_matrix.png")
# Out:
# [2026-03-25 10:03:33] [src.visualization] [INFO] Plotting correlation matrix
# [2026-03-25 10:03:34] [src.visualization] [INFO] Saved correlation matrix figure to D:\Portfolio Projects\diabetes-ml-prediction\reports\figures\correlation_matrix.png
